# %%
from random import random
from bokeh.models import CustomJS, ColumnDataSource
from bokeh.plotting import figure, show

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="30291a69-b0d6-4cfa-8063-a01cfe6f76f8">Loading BokehJS ...</span>
#     </div>

# %%
x = [random() for x in range(500)]
y = [random() for y in range(500)]
color = ["navy"] * len(x)

s = ColumnDataSource(data=dict(x=x, y=y, color=color))
p = figure(plot_width=400, plot_height=400, tools="lasso_select", title="Select Here")
p.circle('x', 'y', color='color', size=8, source=s, alpha=0.4)

s2 = ColumnDataSource(data=dict(x=[0, 1], ym=[0.5, 0.5]))
p.line(x='x', y='ym', color="orange", line_width=5, alpha=0.6, source=s2)

s.callback = CustomJS(args=dict(s2=s2), code="""
        var inds = cb_obj.selected.indices;
        var d = cb_obj.data;
        var ym = 0

        if (inds.length == 0) { return; }

        for (i = 0; i < d['color'].length; i++) {
            d['color'][i] = "navy"
        }
        for (i = 0; i < inds.length; i++) {
            d['color'][inds[i]] = "firebrick"
            ym += d['y'][inds[i]]
        }

        ym /= inds.length
        s2.data['ym'] = [ym, ym]

        cb_obj.change.emit();
        s2.change.emit();
    """)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0767107d-bc8b-4f5a-ac40-9ec9cc8ccf54"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0767107d-bc8b-4f5a-ac40-9ec9cc8ccf54");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0767107d-bc8b-4f5a-ac40-9ec9cc8ccf54");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0767107d-bc8b-4f5a-ac40-9ec9cc8ccf54' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fc227276-1585-4241-bf50-3ea4a27e0540":{"roots":{"references":[{"attributes":{"data_source":{"id":"fe7eec18-64e0-45b8-abb2-c6afd2a77109","type":"ColumnDataSource"},"glyph":{"id":"5acf3745-4dbb-46ea-b7f6-8f3b6f3b240b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0be6c804-f2b8-4644-a959-8a98212c3c1a","type":"Circle"},"selection_glyph":null},"id":"961a9705-5145-45f8-831a-193b214a8090","type":"GlyphRenderer"},{"attributes":{},"id":"37938dee-66f4-4da0-bc4f-f3b0584612f7","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"orange"},"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"ym"}},"id":"f105e0d3-fbbf-4932-9169-91e6f8846e33","type":"Line"},{"attributes":{"below":[{"id":"3f6beddb-117f-477d-8861-2dac9819823b","type":"LinearAxis"}],"left":[{"id":"f0809c1f-843b-4997-8560-1a21835874c2","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"3f6beddb-117f-477d-8861-2dac9819823b","type":"LinearAxis"},{"id":"222f2d04-3cd5-43b3-a592-2032357dde4b","type":"Grid"},{"id":"f0809c1f-843b-4997-8560-1a21835874c2","type":"LinearAxis"},{"id":"475d4750-c51d-46e7-97f6-c61eb60572f2","type":"Grid"},{"id":"369cf775-e0e7-4c19-8b22-6a927580aac7","type":"PolyAnnotation"},{"id":"961a9705-5145-45f8-831a-193b214a8090","type":"GlyphRenderer"},{"id":"38730510-a7f0-4111-b0c0-09d2ec3e03c4","type":"GlyphRenderer"}],"title":{"id":"aa258228-03db-4681-9355-c4d9212468b7","type":"Title"},"tool_events":{"id":"c49c0ed4-dc35-468c-9883-246abdbd79c0","type":"ToolEvents"},"toolbar":{"id":"8b1a92e7-588e-4f59-ba8c-9e0e8df8c8dc","type":"Toolbar"},"x_range":{"id":"9fcd7f76-8773-4784-bc49-5dd80ba48ab8","type":"DataRange1d"},"y_range":{"id":"5d2bc7a7-ed61-48df-b34b-9bc8328fb913","type":"DataRange1d"}},"id":"cce1ba1a-51c1-4c52-a598-c3bd5d4bc520","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"3b42b8e7-a73f-465c-bc8d-30f291ef44a1","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"298e00ae-1ee6-4c8e-95bc-c16955c53b37","type":"ColumnDataSource"},"glyph":{"id":"f105e0d3-fbbf-4932-9169-91e6f8846e33","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f312f908-f6a8-45e9-83f9-8ece10779258","type":"Line"},"selection_glyph":null},"id":"38730510-a7f0-4111-b0c0-09d2ec3e03c4","type":"GlyphRenderer"},{"attributes":{},"id":"16bf61bc-4990-48b2-b8d4-701208dde7d6","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"ym"}},"id":"f312f908-f6a8-45e9-83f9-8ece10779258","type":"Line"},{"attributes":{},"id":"c49c0ed4-dc35-468c-9883-246abdbd79c0","type":"ToolEvents"},{"attributes":{"args":{"s2":{"id":"298e00ae-1ee6-4c8e-95bc-c16955c53b37","type":"ColumnDataSource"}},"code":"\n        var inds = cb_obj.selected.indices;\n        var d = cb_obj.data;\n        var ym = 0\n\n        if (inds.length == 0) { return; }\n\n        for (i = 0; i < d['color'].length; i++) {\n            d['color'][i] = \"navy\"\n        }\n        for (i = 0; i < inds.length; i++) {\n            d['color'][inds[i]] = \"firebrick\"\n            ym += d['y'][inds[i]]\n        }\n\n        ym /= inds.length\n        s2.data['ym'] = [ym, ym]\n\n        cb_obj.change.emit();\n        s2.change.emit();\n    "},"id":"7c58af47-5012-4710-b112-891b1a7521b0","type":"CustomJS"},{"attributes":{"fill_alpha":{"value":0.4},"fill_color":{"field":"color"},"line_alpha":{"value":0.4},"line_color":{"field":"color"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"5acf3745-4dbb-46ea-b7f6-8f3b6f3b240b","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"0be6c804-f2b8-4644-a959-8a98212c3c1a","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{ ...
